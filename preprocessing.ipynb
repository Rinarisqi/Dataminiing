# %% [markdown]
# <a href="https://colab.research.google.com/github/Rinarisqi/Dataminiing/blob/main/preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#coding
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import chardet

# %%
#importdataset 
#pemanggilan Dataset dengan nama nuclearWeaponStates.csv.csv.csv
dataset= pd.read_csv('4ut4a-sc7wf.csv')
X = dataset.iloc[:,:-1].values
Y = dataset.iloc[:,-1].values
print(X)
print(Y)
# Out:
# [[1 'positive']
#  [2 'positive']
#  [3 'negative']
#  [4 'negative']
#  [5 'negative']
#  [6 'negative']
#  [7 'positive']
#  [8 'negative']
#  [9 'negative']
#  [10 'negative']
#  [11 'negative']
#  [12 'negative']
#  [13 'negative']
#  [14 'negative']
#  [15 'negative']
#  [16 'negative']
#  [17 'positive']
#  [18 'negative']
#  [19 'negative']
#  [20 'negative']
#  [21 'negative']
#  [22 'negative']
#  [23 'positive']
#  [24 'positive']
#  [25 'negative']
#  [26 'negative']
#  [27 'negative']
#  [28 'negative']
#  [29 'negative']
#  [30 'negative']
#  [31 'negative']
#  [32 'negative']
#  [33 'positive']
#  [34 'positive']
#  [35 'negative']
#  [36 'negative']
#  [37 'negative']
#  [38 'negative']
#  [39 'negative']
#  [40 'negative']
#  [41 'negative']
#  [42 'positive']
#  [43 'positive']
#  [44 'negative']
#  [45 'positive']
#  [46 'positive']
#  [47 'positive']
#  [48 'negative']
#  [49 'negative']
#  [50 'negative']
#  [51 'positive']
#  [52 'negative']
#  [53 'negative']
# ...

# %%
#Menghilangkan  missing value
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
X[:, 1:3] = imputer.transform(X[:, 1:3])
#missing values = nilai data yang digunakan sebagai penanda bahwa nilai aslinya tidak ada 
#strategy : menggunakan rata-rata kolom mean bisa juga menggunakan median, most_frequent(modus) atau constant

# %%
print(X)
# Out:
# [[1 'positive']
#  [2 'positive']
#  [3 'negative']
#  [4 'negative']
#  [5 'negative']
#  [6 'negative']
#  [7 'positive']
#  [8 'negative']
#  [9 'negative']
#  [10 'negative']
#  [11 'negative']
#  [12 'negative']
#  [13 'negative']
#  [14 'negative']
#  [15 'negative']
#  [16 'negative']
#  [17 'positive']
#  [18 'negative']
#  [19 'negative']
#  [20 'negative']
#  [21 'negative']
#  [22 'negative']
#  [23 'positive']
#  [24 'positive']
#  [25 'negative']
#  [26 'negative']
#  [27 'negative']
#  [28 'negative']
#  [29 'negative']
#  [30 'negative']
#  [31 'negative']
#  [32 'negative']
#  [33 'positive']
#  [34 'positive']
#  [35 'negative']
#  [36 'negative']
#  [37 'negative']
#  [38 'negative']
#  [39 'negative']
#  [40 'negative']
#  [41 'negative']
#  [42 'positive']
#  [43 'positive']
#  [44 'negative']
#  [45 'positive']
#  [46 'positive']
#  [47 'positive']
#  [48 'negative']
#  [49 'negative']
#  [50 'negative']
#  [51 'positive']
#  [52 'negative']
#  [53 'negative']
# ...

# %%
#Enconding Data kategori(Atribut)
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')
X = np.array(ct.fit_transform(X))
print(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sklearn/compose/_column_transformer.py in _hstack(self, Xs)
#     614                                             force_all_finite=False)
# --> 615                                 for X in Xs]
#     616             except ValueError:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/compose/_column_transformer.py in <listcomp>(.0)
#     614                                             force_all_finite=False)
# --> 615                                 for X in Xs]
#     616             except ValueError:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     530                 else:
# ...

# %%
#Membagi dataset ke dalam training set dan test set
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state =1)
print(X_train)
print(X_test)
print(Y_train)
print(Y_test)
# Out:
# [[159 'positive']
#  [151 'positive']
#  [103 'positive']
#  [164 'positive']
#  [113 'positive']
#  [247 'negative']
#  [40 'negative']
#  [171 'positive']
#  [86 'positive']
#  [244 'positive']
#  [283 'negative']
#  [18 'negative']
#  [112 'positive']
#  [132 'positive']
#  [43 'positive']
#  [109 'negative']
#  [293 'positive']
#  [6 'negative']
#  [90 'negative']
#  [39 'negative']
#  [175 'negative']
#  [68 'negative']
#  [257 'negative']
#  [108 'negative']
#  [35 'negative']
#  [182 'positive']
#  [291 'positive']
#  [245 'positive']
#  [198 'positive']
#  [280 'negative']
#  [254 'negative']
#  [20 'negative']
#  [15 'negative']
#  [92 'negative']
#  [297 'positive']
#  [169 'negative']
#  [45 'positive']
#  [281 'negative']
#  [239 'positive']
#  [121 'positive']
#  [260 'negative']
#  [42 'positive']
#  [80 'positive']
#  [284 'negative']
#  [139 'positive']
#  [188 'negative']
#  [262 'negative']
#  [118 'positive']
#  [100 'positive']
#  [9 'negative']
# ...

# %%
#Feature Scaling 
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train[:, 3:] = sc.fit_transform(X_train[:, 3:])
X_test[:, 3:] = sc.trasnform(X_test[:, 3:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-3e97bc7eb442> in <module>()
#       2 from sklearn.preprocessing import StandardScaler
#       3 sc = StandardScaler()
# ----> 4 X_train[:, 3:] = sc.fit_transform(X_train[:, 3:])
#       5 X_test[:, 3:] = sc.trasnform(X_test[:, 3:])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     569         if y is None:
#     570             # fit method of arity 1 (unsupervised transformation)
# --> 571             return self.fit(X, **fit_params).transform(X)
#     572         else:
#     573             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     667         # Reset internal state before fitting
#     668         self._reset()
# ...

# %%
print(X_train)
print(X_test)
# Out:
# [[159 'positive']
#  [151 'positive']
#  [103 'positive']
#  [164 'positive']
#  [113 'positive']
#  [247 'negative']
#  [40 'negative']
#  [171 'positive']
#  [86 'positive']
#  [244 'positive']
#  [283 'negative']
#  [18 'negative']
#  [112 'positive']
#  [132 'positive']
#  [43 'positive']
#  [109 'negative']
#  [293 'positive']
#  [6 'negative']
#  [90 'negative']
#  [39 'negative']
#  [175 'negative']
#  [68 'negative']
#  [257 'negative']
#  [108 'negative']
#  [35 'negative']
#  [182 'positive']
#  [291 'positive']
#  [245 'positive']
#  [198 'positive']
#  [280 'negative']
#  [254 'negative']
#  [20 'negative']
#  [15 'negative']
#  [92 'negative']
#  [297 'positive']
#  [169 'negative']
#  [45 'positive']
#  [281 'negative']
#  [239 'positive']
#  [121 'positive']
#  [260 'negative']
#  [42 'positive']
#  [80 'positive']
#  [284 'negative']
#  [139 'positive']
#  [188 'negative']
#  [262 'negative']
#  [118 'positive']
#  [100 'positive']
#  [9 'negative']
# ...
